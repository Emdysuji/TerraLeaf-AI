# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.6.0

# %%
# Check and display the number of GPUs available for model training

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Define constants for image preprocessing, batching, and training parameters.
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 100

# %%
import cv2
import numpy as np
import os

# Set the path for the main input folder and output folder
input_folder = 'Rice-Leaf-Diseases-Dataset'  
output_folder = 'Rice-Leaf-Diseases-Dataset-Without-Background' 
# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Loop through each subfolder in the main folder
for subfolder_name in os.listdir(input_folder):
    subfolder_path = os.path.join(input_folder, subfolder_name)
    
    # Check if it is a directory
    if os.path.isdir(subfolder_path):
        # Create a corresponding subfolder in the output directory
        output_subfolder = os.path.join(output_folder, subfolder_name)
        os.makedirs(output_subfolder, exist_ok=True)
        
        # Loop through each image file in the subfolder
        for filename in os.listdir(subfolder_path):
            if filename.endswith('.jpg') or filename.endswith('.png'):  # Check for image files
                # Load the image
                image_path = os.path.join(subfolder_path, filename)
                image = cv2.imread(image_path)

                # Convert to grayscale
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

                # Apply Gaussian blur to reduce noise
                blurred = cv2.GaussianBlur(gray, (5, 5), 0)

                # Use adaptive thresholding to create a binary image
                _, binary = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

                # Find contours
                contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

                # Create an empty mask with the same size as the image
                mask = np.zeros_like(gray)

                # Fill the mask with the largest contour (assuming the leaf is the largest object)
                largest_contour = max(contours, key=cv2.contourArea)
                cv2.drawContours(mask, [largest_contour], -1, (255), thickness=cv2.FILLED)

                # Use the mask to extract the leaf from the image
                leaf_only = cv2.bitwise_and(image, image, mask=mask)

                # Make the background transparent
                b, g, r = cv2.split(leaf_only)
                alpha = mask  # Use the mask as the alpha channel
                leaf_with_transparency = cv2.merge([b, g, r, alpha])

                # Save the processed image with transparency
                output_path = os.path.join(output_subfolder, f'processed_{filename}')
                cv2.imwrite(output_path, leaf_with_transparency)

                print(f'Processed and saved: {output_path}')

print("Background removal complete for all images in all subfolders.")

# %%
# Loading the dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Rice-Leaf-Diseases-Dataset-Without-Background",
    shuffle=True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE


)
# Out:
# Found 3355 files belonging to 4 classes.

# %%
# Retrieve and display the class names from the dataset for categorization.
class_names = dataset.class_names
class_names
# Out:
# ['Rice_Brown_spot', 'Rice_Healthy', 'Rice_Hispa', 'Rice_Leaf_blast']

# %%
# Visualize a sample of the images from the dataset along with their labels.

plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.axis("off")
        plt.title(class_names[label_batch[i]])

# %%
# Display the total number of batches in the dataset.
len(dataset)
# Out:
# 105

# %%
# Function to split the dataset into training, validation, and test sets.

def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=1000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12) # Shuffle the dataset for randomness in training
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
# Split the dataset into training, validation, and test partitions.

train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
# Display the number of batches in the training dataset.
len(train_ds)
# Out:
# 84

# %%
# Display the number of batches in the validation dataset.
len(val_ds)
# Out:
# 10

# %%
# Display the number of batches in the testing dataset.
len(test_ds)
# Out:
# 11

# %%
# Apply caching, shuffling, and prefetching to the datasets for better performance during training.

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Define the preprocessing pipeline that resizes and rescales images to a uniform format.

resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
# Define the data augmentation pipeline to apply random transformations to the images.

data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomContrast(0.1),
    
])

# %%
# Build the model architecture by stacking convolutional, pooling, and dense layers.

n_classes = 4
model = models.Sequential([
    layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(64, (3, 3), activation='relu'),  # Increased filters
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(128, (3, 3), activation='relu'),  # Increased filters
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(256, (3, 3), activation='relu'),  # Increased filters
    layers.MaxPooling2D((2, 2)),
    layers.GlobalMaxPooling2D(),
    layers.Dense(256, activation='relu'),  # Increased dense layer size
    layers.Dropout(0.5),
    layers.Dense(n_classes, activation='softmax')
])
model.summary()
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 254, 254, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 256)       0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 437,636
# Trainable params: 437,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model with the Adam optimizer and sparse categorical crossentropy loss function.

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']

)

# %%
# Train the model on the training dataset and validate on the validation dataset.

 history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=val_ds
)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 24s 189ms/step - loss: 1.3221 - accuracy: 0.4309 - val_loss: 1.2656 - val_accuracy: 0.4719
# Epoch 2/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.3002 - accuracy: 0.4365 - val_loss: 1.2598 - val_accuracy: 0.4719
# Epoch 3/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.2338 - accuracy: 0.4652 - val_loss: 1.1256 - val_accuracy: 0.5281
# Epoch 4/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.1880 - accuracy: 0.4927 - val_loss: 1.1299 - val_accuracy: 0.5562
# Epoch 5/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.1584 - accuracy: 0.5147 - val_loss: 1.0613 - val_accuracy: 0.5969
# Epoch 6/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.1164 - accuracy: 0.5494 - val_loss: 1.0946 - val_accuracy: 0.6094
# Epoch 7/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.0701 - accuracy: 0.5762 - val_loss: 0.9253 - val_accuracy: 0.6531
# Epoch 8/100
# 84/84 [==============================] - 12s 138ms/step - loss: 1.0288 - accuracy: 0.6053 - val_loss: 0.9048 - val_accuracy: 0.6656
# Epoch 9/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.9782 - accuracy: 0.6250 - val_loss: 0.8574 - val_accuracy: 0.6969
# Epoch 10/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.9506 - accuracy: 0.6332 - val_loss: 0.8524 - val_accuracy: 0.6875
# Epoch 11/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.9389 - accuracy: 0.6351 - val_loss: 0.9368 - val_accuracy: 0.6219
# Epoch 12/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.9220 - accuracy: 0.6385 - val_loss: 0.8995 - val_accuracy: 0.6438
# Epoch 13/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.9268 - accuracy: 0.6448 - val_loss: 0.8193 - val_accuracy: 0.6875
# Epoch 14/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.8937 - accuracy: 0.6590 - val_loss: 0.8101 - val_accuracy: 0.7063
# Epoch 15/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.8589 - accuracy: 0.6776 - val_loss: 0.7947 - val_accuracy: 0.7188
# Epoch 16/100
# 84/84 [==============================] - 11s 137ms/step - loss: 0.8454 - accuracy: 0.6754 - val_loss: 0.7473 - val_accuracy: 0.7063
# Epoch 17/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.8455 - accuracy: 0.6724 - val_loss: 0.7933 - val_accuracy: 0.6969
# Epoch 18/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.8405 - accuracy: 0.6761 - val_loss: 0.7446 - val_accuracy: 0.7188
# Epoch 19/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.8225 - accuracy: 0.6821 - val_loss: 0.7396 - val_accuracy: 0.7344
# Epoch 20/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.8036 - accuracy: 0.6985 - val_loss: 0.7231 - val_accuracy: 0.7094
# Epoch 21/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7733 - accuracy: 0.6988 - val_loss: 0.7159 - val_accuracy: 0.7188
# Epoch 22/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7684 - accuracy: 0.7082 - val_loss: 0.6963 - val_accuracy: 0.7219
# Epoch 23/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7706 - accuracy: 0.7048 - val_loss: 0.7191 - val_accuracy: 0.7156
# Epoch 24/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.7585 - accuracy: 0.7141 - val_loss: 0.6710 - val_accuracy: 0.7469
# Epoch 25/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7440 - accuracy: 0.7179 - val_loss: 0.6926 - val_accuracy: 0.7125
# Epoch 26/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.7509 - accuracy: 0.7089 - val_loss: 0.6994 - val_accuracy: 0.7063
# Epoch 27/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.7397 - accuracy: 0.7093 - val_loss: 0.6812 - val_accuracy: 0.7500
# Epoch 28/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7300 - accuracy: 0.7268 - val_loss: 0.7068 - val_accuracy: 0.7219
# Epoch 29/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7214 - accuracy: 0.7261 - val_loss: 0.6979 - val_accuracy: 0.7125
# Epoch 30/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.7207 - accuracy: 0.7290 - val_loss: 0.6808 - val_accuracy: 0.7281
# Epoch 31/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.7082 - accuracy: 0.7350 - val_loss: 0.6787 - val_accuracy: 0.7156
# Epoch 32/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6939 - accuracy: 0.7324 - val_loss: 0.6707 - val_accuracy: 0.7312
# Epoch 33/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.7026 - accuracy: 0.7384 - val_loss: 0.6308 - val_accuracy: 0.7531
# Epoch 34/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6929 - accuracy: 0.7391 - val_loss: 0.6547 - val_accuracy: 0.7312
# Epoch 35/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.6887 - accuracy: 0.7365 - val_loss: 0.6260 - val_accuracy: 0.7437
# Epoch 36/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.6872 - accuracy: 0.7410 - val_loss: 0.6151 - val_accuracy: 0.7594
# Epoch 37/100
# 84/84 [==============================] - 12s 144ms/step - loss: 0.6841 - accuracy: 0.7477 - val_loss: 0.6037 - val_accuracy: 0.7625
# Epoch 38/100
# 84/84 [==============================] - 12s 140ms/step - loss: 0.6771 - accuracy: 0.7447 - val_loss: 0.5962 - val_accuracy: 0.7375
# Epoch 39/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6762 - accuracy: 0.7402 - val_loss: 0.6513 - val_accuracy: 0.7406
# Epoch 40/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6761 - accuracy: 0.7417 - val_loss: 0.6237 - val_accuracy: 0.7656
# Epoch 41/100
# 84/84 [==============================] - 12s 140ms/step - loss: 0.6520 - accuracy: 0.7596 - val_loss: 0.6021 - val_accuracy: 0.7781
# Epoch 42/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.6702 - accuracy: 0.7533 - val_loss: 0.6428 - val_accuracy: 0.7281
# Epoch 43/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6667 - accuracy: 0.7477 - val_loss: 0.5933 - val_accuracy: 0.7906
# Epoch 44/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.6519 - accuracy: 0.7592 - val_loss: 0.5862 - val_accuracy: 0.8062
# Epoch 45/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.6555 - accuracy: 0.7641 - val_loss: 0.5718 - val_accuracy: 0.7812
# Epoch 46/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6424 - accuracy: 0.7562 - val_loss: 0.6412 - val_accuracy: 0.7656
# Epoch 47/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.6292 - accuracy: 0.7637 - val_loss: 0.5502 - val_accuracy: 0.7937
# Epoch 48/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6393 - accuracy: 0.7607 - val_loss: 0.5686 - val_accuracy: 0.7781
# Epoch 49/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6363 - accuracy: 0.7577 - val_loss: 0.6134 - val_accuracy: 0.7500
# Epoch 50/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6321 - accuracy: 0.7637 - val_loss: 0.5614 - val_accuracy: 0.7969
# Epoch 51/100
# 84/84 [==============================] - 12s 139ms/step - loss: 0.6301 - accuracy: 0.7615 - val_loss: 0.6325 - val_accuracy: 0.7656
# Epoch 52/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6258 - accuracy: 0.7715 - val_loss: 0.5995 - val_accuracy: 0.7594
# Epoch 53/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6423 - accuracy: 0.7518 - val_loss: 0.5668 - val_accuracy: 0.7906
# Epoch 54/100
# 84/84 [==============================] - 12s 140ms/step - loss: 0.6150 - accuracy: 0.7700 - val_loss: 0.5337 - val_accuracy: 0.8062
# Epoch 55/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6108 - accuracy: 0.7700 - val_loss: 0.5598 - val_accuracy: 0.7875
# Epoch 56/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6181 - accuracy: 0.7697 - val_loss: 0.5655 - val_accuracy: 0.8000
# Epoch 57/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6099 - accuracy: 0.7637 - val_loss: 0.5377 - val_accuracy: 0.8000
# Epoch 58/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6090 - accuracy: 0.7663 - val_loss: 0.5687 - val_accuracy: 0.7812
# Epoch 59/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6006 - accuracy: 0.7764 - val_loss: 0.5603 - val_accuracy: 0.7625
# Epoch 60/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.5886 - accuracy: 0.7794 - val_loss: 0.5610 - val_accuracy: 0.7969
# Epoch 61/100
# 84/84 [==============================] - 12s 141ms/step - loss: 0.6196 - accuracy: 0.7667 - val_loss: 0.6222 - val_accuracy: 0.7500
# Epoch 62/100
# 84/84 [==============================] - 12s 140ms/step - loss: 0.5901 - accuracy: 0.7853 - val_loss: 0.5526 - val_accuracy: 0.7906
# Epoch 63/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5926 - accuracy: 0.7719 - val_loss: 0.5261 - val_accuracy: 0.8062
# Epoch 64/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.6047 - accuracy: 0.7715 - val_loss: 0.5040 - val_accuracy: 0.8156
# Epoch 65/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5824 - accuracy: 0.7887 - val_loss: 0.6344 - val_accuracy: 0.7000
# Epoch 66/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5758 - accuracy: 0.7782 - val_loss: 0.5449 - val_accuracy: 0.7969
# Epoch 67/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5729 - accuracy: 0.7861 - val_loss: 0.5284 - val_accuracy: 0.8125
# Epoch 68/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5816 - accuracy: 0.7924 - val_loss: 0.5529 - val_accuracy: 0.7906
# Epoch 69/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5713 - accuracy: 0.7857 - val_loss: 0.5120 - val_accuracy: 0.8062
# Epoch 70/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5690 - accuracy: 0.7827 - val_loss: 0.5113 - val_accuracy: 0.8313
# Epoch 71/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5621 - accuracy: 0.7898 - val_loss: 0.5382 - val_accuracy: 0.7875
# Epoch 72/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5448 - accuracy: 0.7958 - val_loss: 0.5264 - val_accuracy: 0.8219
# Epoch 73/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5811 - accuracy: 0.7816 - val_loss: 0.5277 - val_accuracy: 0.8031
# Epoch 74/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5652 - accuracy: 0.7920 - val_loss: 0.5434 - val_accuracy: 0.7812
# Epoch 75/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5518 - accuracy: 0.7976 - val_loss: 0.5120 - val_accuracy: 0.8062
# Epoch 76/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5954 - accuracy: 0.7767 - val_loss: 0.4811 - val_accuracy: 0.8188
# Epoch 77/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5453 - accuracy: 0.8062 - val_loss: 0.5081 - val_accuracy: 0.8281
# Epoch 78/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5365 - accuracy: 0.8025 - val_loss: 0.5022 - val_accuracy: 0.8156
# Epoch 79/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5390 - accuracy: 0.8002 - val_loss: 0.4947 - val_accuracy: 0.8250
# Epoch 80/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5517 - accuracy: 0.7935 - val_loss: 0.5231 - val_accuracy: 0.8031
# Epoch 81/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5274 - accuracy: 0.8040 - val_loss: 0.5246 - val_accuracy: 0.7969
# Epoch 82/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5349 - accuracy: 0.8010 - val_loss: 0.5277 - val_accuracy: 0.8375
# Epoch 83/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5283 - accuracy: 0.7961 - val_loss: 0.5334 - val_accuracy: 0.7844
# Epoch 84/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5338 - accuracy: 0.8054 - val_loss: 0.4578 - val_accuracy: 0.8438
# Epoch 85/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5221 - accuracy: 0.7995 - val_loss: 0.5004 - val_accuracy: 0.8031
# Epoch 86/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5233 - accuracy: 0.8069 - val_loss: 0.4933 - val_accuracy: 0.8125
# Epoch 87/100
# 84/84 [==============================] - 12s 138ms/step - loss: 0.5240 - accuracy: 0.8136 - val_loss: 0.4831 - val_accuracy: 0.8219
# Epoch 88/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5184 - accuracy: 0.8159 - val_loss: 0.4515 - val_accuracy: 0.8469
# Epoch 89/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5375 - accuracy: 0.8017 - val_loss: 0.4785 - val_accuracy: 0.8250
# Epoch 90/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5297 - accuracy: 0.7976 - val_loss: 0.5428 - val_accuracy: 0.7781
# Epoch 91/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5078 - accuracy: 0.8122 - val_loss: 0.4947 - val_accuracy: 0.8125
# Epoch 92/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5463 - accuracy: 0.7917 - val_loss: 0.4936 - val_accuracy: 0.8219
# Epoch 93/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5097 - accuracy: 0.8170 - val_loss: 0.4827 - val_accuracy: 0.8250
# Epoch 94/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5042 - accuracy: 0.8133 - val_loss: 0.4556 - val_accuracy: 0.8469
# Epoch 95/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5096 - accuracy: 0.8125 - val_loss: 0.4666 - val_accuracy: 0.8219
# Epoch 96/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5268 - accuracy: 0.8028 - val_loss: 0.4629 - val_accuracy: 0.8375
# Epoch 97/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5047 - accuracy: 0.8114 - val_loss: 0.4622 - val_accuracy: 0.8438
# Epoch 98/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.4902 - accuracy: 0.8166 - val_loss: 0.4613 - val_accuracy: 0.8438
# Epoch 99/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.5036 - accuracy: 0.8125 - val_loss: 0.5655 - val_accuracy: 0.8000
# Epoch 100/100
# 84/84 [==============================] - 12s 137ms/step - loss: 0.4909 - accuracy: 0.8230 - val_loss: 0.4456 - val_accuracy: 0.8375

# %%
# Evaluate the model performance on the test dataset.

scores = model.evaluate(test_ds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 scores = model.evaluate(test_ds)
#
# NameError: name 'model' is not defined

# %%
# Store the training and validation accuracy and loss for visualization.

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Visualize the training and validation accuracy and loss over the epochs.

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label="Training Accuracy")
plt.plot(range(EPOCHS), val_acc, label="Validation Accuracy")
plt.legend(loc='lower right')
plt.title("Training and Validation Accuracy")

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label="Training Loss")
plt.plot(range(EPOCHS), val_loss, label="Validation Loss")
plt.legend(loc='upper right')
plt.title("Training and Validation Loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
# Display a sample image along with its predicted label for visual inspection.

for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label: ", class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label: ",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label:  Rice_Brown_spot
# predicted label:  Rice_Brown_spot

# %%
# Save the trained model with versioning to manage different model iterations.
models_dir = "../models"  # Adjust the path as necessary

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

model_name = "model_version"

model_version = max(
    [int(i.split('_v')[-1].split('.')[0]) for i in os.listdir(models_dir) if i.startswith(model_name)] + [0]
) + 1

model_save_path = f"{models_dir}/{model_name}_v{model_version}.keras"
model.save(model_save_path)

# %%
# Load the .keras model
model = tf.keras.models.load_model('../models/model_version_v1.keras')

# %%
scores = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 21s 144ms/step - loss: 0.4799 - accuracy: 0.8125

# %%
# Calculate precision, recall, and F1 score for the model's predictions on the test set.

from sklearn.metrics import precision_score, recall_score, f1_score

# Initialize lists to store true and predicted labels
y_true = []
y_pred = []

# Iterate over the test dataset to collect true and predicted labels
for images, labels in test_ds:
    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = labels.numpy()
    
    y_pred.extend(predicted_classes)
    y_true.extend(true_classes)

# Convert lists to numpy arrays for metric calculation
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Compute the metrics
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.81805144431803
# Recall: 0.8125
# F1 Score: 0.8112992250592271
